# %% [markdown]
# CH-31

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
x=[[1],[2],[3],[4]]
y=[2,4,6,8]
model.fit(x,y)
predection=model.predict([[10]])
print("Prediction for input 5 is:" , predection)
# Out:
# Prediction for input 5 is: [20.]

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
x=[[1],[2],[3],[4]]
y=[2,4,6,8]
model.fit(x,y)
user_value=float(input("Enter a number to predict:"))
prediction= model.predict([[user_value]])
print("pridection is:",predection[0])
# Out:
# Enter a number to predict: 10
# pridection is: 20.0

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color="blue",label='data points')
plt.plot(x, model.predict(x), color='orange', label='Regression Line')
plt.legend(loc='center left',bbox_to_anchor=(1, 0.5))
plt.title("linear regression line")
plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
x=[[1],[2],[3],[4],[5]]
y=[12,20,26,30,38]
model.fit(x,y)
predection=model.predict([[10]])
print("Prediction for input 5 is:" , predection)
# Out:
# Prediction for input 5 is: [68.6]

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
x=[[1],[2],[3],[4],[5]]
y=[12,20,26,30,38]
model.fit(x,y)
user_value=float(input("Enter a number to predict:"))
prediction= model.predict([[user_value]])
print("pridection is:",predection[0])
# Out:
# Enter a number to predict: 20
# pridection is: 80.0

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color="green",label='data points')
plt.plot(x, model.predict(x), color='yellow', label='BANANA PRICE')
plt.legend(loc='center left',bbox_to_anchor=(1, 0.5))
plt.title("BANANA PRICE")
plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
plt.show()

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
x=[[1],[2],[3],[4],[5],[6]]
y=[35,40,45,50,55,60]
model.fit(x,y)
predection=model.predict([[10]])
print("Prediction for input 5 is:" , predection)
# Out:
# Prediction for input 5 is: [80.]

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
x=[[1],[2],[3],[4],[5],[6]]
y=[35,40,45,50,55,60]
model.fit(x,y)
user_value=float(input("Enter a number to predict:"))
prediction= model.predict([[user_value]])
print("pridection is:",predection[0])
# Out:
# Enter a number to predict: 10
# pridection is: 80.0

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color="blue",label='data points')
plt.plot(x, model.predict(x), color='orange', label='score')
plt.legend(loc='center left',bbox_to_anchor=(1, 0.5))
plt.title("score")
plt.xlabel("x")
plt.ylabel("y")
plt.tight_layout()
plt.show()
